# %% [markdown]
# # import   packages

# %%
import glob
import os
import librosa as lib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa.display
import numpy as np
import IPython.display as ipd
import shutil
import soundfile
from tqdm import tqdm
from sklearn.model_selection import StratifiedShuffleSplit
import shutil
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # import   packages

# %%
def get_files(path):
    files = [file for file in glob.glob(path)]
    return files
def create_dataset(dataset,folder):
    data1 = {"file_path":[],"label":[]}
    unlabelled_files = ["Aunlabelledtest", "Bunlabelledtest"]
    files = get_files(folder + "//**")
    for file in files:
        label = os.path.basename(file).split("_")[0]
        if ((librosa.get_duration(filename=file)>=3) and (label not in unlabelled_files)):
            data1["file_path"].append(file)
            data1["label"].append(label)

    dataset = pd.DataFrame(data1)
    return dataset

# %%
data_audio = create_dataset("/set_a","/content/drive/MyDrive/English Accent/set_a")
data_audio
# Out:
# <ipython-input-3-2ed4ef0e4e4e>:10: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   if ((librosa.get_duration(filename=file)>=3) and (label not in unlabelled_files)):
#                                             file_path    label
# 0   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 1   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 2   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 3   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 4   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 5   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 6   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 7   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 8   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 9   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 10  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 11  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 12  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 13  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 14  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 15  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 16  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 17  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 18  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 19  /content/drive/MyDrive/English Accent/set_a/In...   Indian

# %%
data_audio.label.value_counts()
# Out:
# label
# Indian     11
# America     9
# Name: count, dtype: int64

# %% [markdown]
# # Visualization of data

# %%
def data_distribution(data):
    plt.figure(figsize=(16,3))
    data.label.value_counts().plot(kind='pie', title="audio Data Category")
    plt.show()
def waveform(file_path,label):
    y, sr = lib.load(file_path)
    plt.figure(figsize=(16,3))
    plt.title(label + " Sound Wave")
    lib.display.waveshow(y)

def spectrogram(file_path,label):
    y, sr = lib.load(file_path)
    plt.figure(figsize=(16,3))
    plt.title(label + "  Spectrogram")
    data = lib.amplitude_to_db(np.abs(lib.stft(y)), ref=np.max)
    lib.display.specshow(data, y_axis='log',x_axis='time')
    plt.colorbar();

# %%
data_labels =data_audio.label.unique()
data_labels
# Out:
# array(['America', 'Indian'], dtype=object)

# %%
import librosa as lib
import matplotlib.pyplot as plt

path = data_audio[data_audio.label==data_labels[0]].file_path.iloc[3]
print(path)
waveform(path,data_labels[0])
spectrogram(path,data_labels[0])
ipd.Audio(path)
# Out:
# /content/drive/MyDrive/English Accent/set_a/America_002.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = data_audio[data_audio.label==data_labels[1]].file_path.iloc[0]
print(path)
waveform(path,data_labels[1])
spectrogram(path,data_labels[1])
ipd.Audio(path)
# Out:
# /content/drive/MyDrive/English Accent/set_a/Indian_008.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
main_data = create_dataset("/set_a","/content/drive/MyDrive/English Accent/set_a")
main_data
# Out:
# <ipython-input-3-2ed4ef0e4e4e>:10: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   if ((librosa.get_duration(filename=file)>=3) and (label not in unlabelled_files)):
#                                             file_path    label
# 0   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 1   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 2   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 3   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 4   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 5   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 6   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 7   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 8   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 9   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 10  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 11  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 12  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 13  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 14  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 15  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 16  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 17  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 18  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 19  /content/drive/MyDrive/English Accent/set_a/In...   Indian

# %%
main_data.label.value_counts()
# Out:
# label
# Indian     11
# America     9
# Name: count, dtype: int64

# %%
data_distribution(main_data)

# %% [markdown]
# # Train and Test split

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in split.split(main_data, main_data.label):
    train = main_data.loc[train_idx]
    test = main_data.loc[test_idx]

# %%
train
# Out:
#                                             file_path    label
# 1   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 8   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 3   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 0   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 16  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 7   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 11  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 19  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 10  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 4   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 18  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 9   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 14  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 15  /content/drive/MyDrive/English Accent/set_a/Am...  America
# 17  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 2   /content/drive/MyDrive/English Accent/set_a/Am...  America

# %%
test
# Out:
#                                             file_path    label
# 6   /content/drive/MyDrive/English Accent/set_a/Am...  America
# 5   /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 13  /content/drive/MyDrive/English Accent/set_a/In...   Indian
# 12  /content/drive/MyDrive/English Accent/set_a/Am...  America

# %% [markdown]
# # MFCC

# %%
# MFCC
def feature_extraction(file_path):
    y, sr = lib.load(file_path, duration=3)
    mfcc = lib.feature.mfcc(y=y, sr=sr,n_mfcc=128)
    return mfcc

# %%
x_train = np.asarray([feature_extraction(train.file_path.iloc[i]) for i in (range(len(train)))])
x_test = np.asarray([feature_extraction(test.file_path.iloc[i]) for i in (range(len(test)))])

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)

print("X_Train Shape: ", x_train.shape)
print("X_Test Shape: ", x_test.shape)
# Out:
# X_Train Shape:  (16, 128, 130, 1)
# X_Test Shape:  (4, 128, 130, 1)

# %%
#Encode the labels into numbers from string values
encode = LabelEncoder()
y_train = encode.fit_transform(train.label)
y_test = encode.fit_transform(test.label)

# %%
#Setting 5 labels for each audio example with their probabilities
y_train = to_categorical(y_train,num_classes=2)
y_test = to_categorical(y_test,num_classes=2)

print("Y_Train Shape: ", y_train.shape)
print("Y_Test Shape: ", y_test.shape)
# Out:
# Y_Train Shape:  (16, 2)
# Y_Test Shape:  (4, 2)

# %% [markdown]
# # CNN algorithm

# %%
#Creating a CNN model
def CNN_model(n_width,n_height,n_channels,n_dropout,n_classes):
    cnn_model = Sequential()

    cnn_model.add(Conv2D(filters=24, kernel_size=(5,5), strides=(1, 1),input_shape=(n_width,n_height,n_channels), activation ='relu'))
    cnn_model.add(MaxPooling2D((4, 2), strides=(4, 2)))

    cnn_model.add(Conv2D(filters=48, kernel_size=(5,5), padding = 'valid', activation ='relu'))
    cnn_model.add(MaxPooling2D((4, 2), strides=(4, 2)))

    cnn_model.add(Conv2D(filters=48, kernel_size=(5,5), padding = 'valid', activation ='relu'))

    cnn_model.add(Flatten())
    cnn_model.add(Dropout(rate=n_dropout))

    cnn_model.add(Dense(64, activation ='relu'))
    cnn_model.add(Dropout(rate=n_dropout))

    cnn_model.add(Dense(2, activation ='softmax'))

    return cnn_model

# %%
model = CNN_model(x_train.shape[1],x_train.shape[2],x_train.shape[3],0.5,len(encode.classes_))

optimizer = Adam(lr=0.0001)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 126, 24)      624
#
#  max_pooling2d (MaxPooling2  (None, 31, 63, 24)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 27, 59, 48)        28848
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 29, 48)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 25, 48)         57648
#
#  flatten (Flatten)           (None, 2400)              0
#
#  dropout (Dropout)           (None, 2400)              0
#
#  dense (Dense)               (None, 64)                153664
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 240914 (941.07 KB)
# Trainable params: 240914 (941.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# %%time
batch_size = 128
file = 'model_file.hdf5'
path = os.path.join(file)

checkpoints = ModelCheckpoint(filepath=path,save_best_only=True,verbose=1)
# Out:
# CPU times: user 91 µs, sys: 8 µs, total: 99 µs
# Wall time: 105 µs

# %%
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=100, validation_data=(x_test, y_test),
                        callbacks=[checkpoints],verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 2.4497 - accuracy: 0.7500
# Epoch 1: val_loss improved from inf to 1.02980, saving model to model_file.hdf5
# 1/1 [==============================] - 3s 3s/step - loss: 2.4497 - accuracy: 0.7500 - val_loss: 1.0298 - val_accuracy: 0.5000
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - ETA: 0s - loss: 3.3538 - accuracy: 0.5625
# Epoch 2: val_loss did not improve from 1.02980
# 1/1 [==============================] - 1s 551ms/step - loss: 3.3538 - accuracy: 0.5625 - val_loss: 1.1649 - val_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 2.8058 - accuracy: 0.5625
# Epoch 3: val_loss improved from 1.02980 to 0.70116, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 357ms/step - loss: 2.8058 - accuracy: 0.5625 - val_loss: 0.7012 - val_accuracy: 0.2500
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 2.7128 - accuracy: 0.5000
# Epoch 4: val_loss did not improve from 0.70116
# 1/1 [==============================] - 0s 305ms/step - loss: 2.7128 - accuracy: 0.5000 - val_loss: 2.7168 - val_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 3.7563 - accuracy: 0.5000
# Epoch 5: val_loss did not improve from 0.70116
# 1/1 [==============================] - 0s 303ms/step - loss: 3.7563 - accuracy: 0.5000 - val_loss: 2.2289 - val_accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 2.2790 - accuracy: 0.5000
# Epoch 6: val_loss did not improve from 0.70116
# 1/1 [==============================] - 0s 291ms/step - loss: 2.2790 - accuracy: 0.5000 - val_loss: 0.7579 - val_accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3450 - accuracy: 0.6250
# Epoch 7: val_loss improved from 0.70116 to 0.46789, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 318ms/step - loss: 1.3450 - accuracy: 0.6250 - val_loss: 0.4679 - val_accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 2.8668 - accuracy: 0.5625
# Epoch 8: val_loss did not improve from 0.46789
# 1/1 [==============================] - 0s 299ms/step - loss: 2.8668 - accuracy: 0.5625 - val_loss: 0.6926 - val_accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8783 - accuracy: 0.6250
# Epoch 9: val_loss did not improve from 0.46789
# 1/1 [==============================] - 0s 314ms/step - loss: 1.8783 - accuracy: 0.6250 - val_loss: 0.8084 - val_accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3103 - accuracy: 0.7500
# Epoch 10: val_loss did not improve from 0.46789
# 1/1 [==============================] - 0s 296ms/step - loss: 1.3103 - accuracy: 0.7500 - val_loss: 0.5644 - val_accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0749 - accuracy: 0.7500
# Epoch 11: val_loss did not improve from 0.46789
# 1/1 [==============================] - 0s 282ms/step - loss: 1.0749 - accuracy: 0.7500 - val_loss: 0.4746 - val_accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.0450 - accuracy: 0.6250
# Epoch 12: val_loss improved from 0.46789 to 0.46654, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 344ms/step - loss: 1.0450 - accuracy: 0.6250 - val_loss: 0.4665 - val_accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.6875
# Epoch 13: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 292ms/step - loss: 0.5975 - accuracy: 0.6875 - val_loss: 0.4851 - val_accuracy: 0.7500
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.8750
# Epoch 14: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 304ms/step - loss: 0.3794 - accuracy: 0.8750 - val_loss: 0.5013 - val_accuracy: 0.7500
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.8125
# Epoch 15: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4710 - accuracy: 0.8125 - val_loss: 0.5194 - val_accuracy: 0.7500
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.9527 - accuracy: 0.5625
# Epoch 16: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 301ms/step - loss: 0.9527 - accuracy: 0.5625 - val_loss: 0.5200 - val_accuracy: 0.7500
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.8750
# Epoch 17: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6490 - accuracy: 0.8750 - val_loss: 0.5033 - val_accuracy: 0.7500
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.6875
# Epoch 18: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4721 - accuracy: 0.6875 - val_loss: 0.5077 - val_accuracy: 0.7500
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6250
# Epoch 19: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 285ms/step - loss: 0.6359 - accuracy: 0.6250 - val_loss: 0.5207 - val_accuracy: 0.7500
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4737 - accuracy: 0.8125
# Epoch 20: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 290ms/step - loss: 0.4737 - accuracy: 0.8125 - val_loss: 0.5375 - val_accuracy: 0.7500
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.7500
# Epoch 21: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 292ms/step - loss: 0.4542 - accuracy: 0.7500 - val_loss: 0.5256 - val_accuracy: 0.7500
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4022 - accuracy: 0.8125
# Epoch 22: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 300ms/step - loss: 0.4022 - accuracy: 0.8125 - val_loss: 0.5139 - val_accuracy: 0.7500
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3990 - accuracy: 0.8125
# Epoch 23: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 293ms/step - loss: 0.3990 - accuracy: 0.8125 - val_loss: 0.5276 - val_accuracy: 0.7500
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5177 - accuracy: 0.7500
# Epoch 24: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 287ms/step - loss: 0.5177 - accuracy: 0.7500 - val_loss: 0.5413 - val_accuracy: 0.7500
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8750
# Epoch 25: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 299ms/step - loss: 0.3751 - accuracy: 0.8750 - val_loss: 0.5269 - val_accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4400 - accuracy: 0.8750
# Epoch 26: val_loss did not improve from 0.46654
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4400 - accuracy: 0.8750 - val_loss: 0.4859 - val_accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.8138 - accuracy: 0.5000
# Epoch 27: val_loss improved from 0.46654 to 0.45184, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 348ms/step - loss: 0.8138 - accuracy: 0.5000 - val_loss: 0.4518 - val_accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5519 - accuracy: 0.8125
# Epoch 28: val_loss improved from 0.45184 to 0.39618, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 341ms/step - loss: 0.5519 - accuracy: 0.8125 - val_loss: 0.3962 - val_accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8750
# Epoch 29: val_loss improved from 0.39618 to 0.35614, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 349ms/step - loss: 0.3157 - accuracy: 0.8750 - val_loss: 0.3561 - val_accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8125
# Epoch 30: val_loss improved from 0.35614 to 0.34862, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 312ms/step - loss: 0.3346 - accuracy: 0.8125 - val_loss: 0.3486 - val_accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.7500
# Epoch 31: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 290ms/step - loss: 0.5250 - accuracy: 0.7500 - val_loss: 0.3553 - val_accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.5138 - accuracy: 0.7500
# Epoch 32: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 314ms/step - loss: 0.5138 - accuracy: 0.7500 - val_loss: 0.3801 - val_accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8125
# Epoch 33: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 288ms/step - loss: 0.3274 - accuracy: 0.8125 - val_loss: 0.3812 - val_accuracy: 0.7500
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8750
# Epoch 34: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 298ms/step - loss: 0.2986 - accuracy: 0.8750 - val_loss: 0.3655 - val_accuracy: 0.7500
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8750
# Epoch 35: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 428ms/step - loss: 0.2784 - accuracy: 0.8750 - val_loss: 0.3725 - val_accuracy: 0.7500
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8125
# Epoch 36: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 492ms/step - loss: 0.3128 - accuracy: 0.8125 - val_loss: 0.3619 - val_accuracy: 0.7500
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.7500
# Epoch 37: val_loss did not improve from 0.34862
# 1/1 [==============================] - 1s 505ms/step - loss: 0.3372 - accuracy: 0.7500 - val_loss: 0.3501 - val_accuracy: 0.7500
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8125
# Epoch 38: val_loss did not improve from 0.34862
# 1/1 [==============================] - 0s 481ms/step - loss: 0.2854 - accuracy: 0.8125 - val_loss: 0.3492 - val_accuracy: 0.7500
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.8750
# Epoch 39: val_loss improved from 0.34862 to 0.34262, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 561ms/step - loss: 0.2529 - accuracy: 0.8750 - val_loss: 0.3426 - val_accuracy: 0.7500
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8750
# Epoch 40: val_loss improved from 0.34262 to 0.28827, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 531ms/step - loss: 0.2711 - accuracy: 0.8750 - val_loss: 0.2883 - val_accuracy: 0.7500
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.8750
# Epoch 41: val_loss improved from 0.28827 to 0.21994, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 536ms/step - loss: 0.2825 - accuracy: 0.8750 - val_loss: 0.2199 - val_accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1727 - accuracy: 0.9375
# Epoch 42: val_loss improved from 0.21994 to 0.18104, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 508ms/step - loss: 0.1727 - accuracy: 0.9375 - val_loss: 0.1810 - val_accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9375
# Epoch 43: val_loss improved from 0.18104 to 0.16582, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 519ms/step - loss: 0.2121 - accuracy: 0.9375 - val_loss: 0.1658 - val_accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9375
# Epoch 44: val_loss improved from 0.16582 to 0.15028, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 577ms/step - loss: 0.1137 - accuracy: 0.9375 - val_loss: 0.1503 - val_accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.8750
# Epoch 45: val_loss did not improve from 0.15028
# 1/1 [==============================] - 1s 512ms/step - loss: 0.2287 - accuracy: 0.8750 - val_loss: 0.1615 - val_accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3046 - accuracy: 0.8750
# Epoch 46: val_loss improved from 0.15028 to 0.12437, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 326ms/step - loss: 0.3046 - accuracy: 0.8750 - val_loss: 0.1244 - val_accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9375
# Epoch 47: val_loss improved from 0.12437 to 0.10488, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1347 - accuracy: 0.9375 - val_loss: 0.1049 - val_accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.10488 to 0.09456, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 328ms/step - loss: 0.1358 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9375
# Epoch 49: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 293ms/step - loss: 0.2292 - accuracy: 0.9375 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9375
# Epoch 50: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1562 - accuracy: 0.9375 - val_loss: 0.1795 - val_accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 0.2361 - val_accuracy: 0.7500
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1108 - accuracy: 1.0000 - val_loss: 0.2459 - val_accuracy: 0.7500
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0993 - accuracy: 1.0000 - val_loss: 0.2421 - val_accuracy: 0.7500
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 0.2325 - val_accuracy: 0.7500
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9375
# Epoch 55: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 304ms/step - loss: 0.2171 - accuracy: 0.9375 - val_loss: 0.2308 - val_accuracy: 0.7500
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9375
# Epoch 56: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 290ms/step - loss: 0.2188 - accuracy: 0.9375 - val_loss: 0.2228 - val_accuracy: 0.7500
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9375
# Epoch 57: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1040 - accuracy: 0.9375 - val_loss: 0.2051 - val_accuracy: 0.7500
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9375
# Epoch 58: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1139 - accuracy: 0.9375 - val_loss: 0.2396 - val_accuracy: 0.7500
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.7500
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9375
# Epoch 60: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1428 - accuracy: 0.9375 - val_loss: 0.2346 - val_accuracy: 0.7500
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8750
# Epoch 61: val_loss did not improve from 0.09456
# 1/1 [==============================] - 0s 293ms/step - loss: 0.3059 - accuracy: 0.8750 - val_loss: 0.1390 - val_accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 62: val_loss improved from 0.09456 to 0.08941, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 342ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.08941 to 0.05611, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 1.0000
# Epoch 64: val_loss improved from 0.05611 to 0.04610, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 320ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 1.0000
# Epoch 65: val_loss improved from 0.04610 to 0.04009, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 1.0000
# Epoch 66: val_loss improved from 0.04009 to 0.03823, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 1.0000
# Epoch 67: val_loss improved from 0.03823 to 0.03754, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9375
# Epoch 68: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0831 - accuracy: 0.9375 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9375
# Epoch 74: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0795 - accuracy: 0.9375 - val_loss: 0.1430 - val_accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.03754
# 1/1 [==============================] - 0s 391ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 79: val_loss improved from 0.03754 to 0.02205, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 533ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 80: val_loss improved from 0.02205 to 0.01324, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 577ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 81: val_loss improved from 0.01324 to 0.00861, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 82: val_loss improved from 0.00861 to 0.00584, saving model to model_file.hdf5
# 1/1 [==============================] - 1s 567ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9375
# Epoch 84: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 461ms/step - loss: 0.0707 - accuracy: 0.9375 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 478ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.00584
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.00584
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 431ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 7.1247e-04 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 300ms/step - loss: 7.1247e-04 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9375
# Epoch 91: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0819 - accuracy: 0.9375 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 94: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 95: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 1.0000
# Epoch 96: val_loss did not improve from 0.00584
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9375
# Epoch 97: val_loss improved from 0.00584 to 0.00461, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 367ms/step - loss: 0.0650 - accuracy: 0.9375 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 98: val_loss improved from 0.00461 to 0.00198, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 99: val_loss improved from 0.00198 to 0.00103, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 348ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 100: val_loss improved from 0.00103 to 0.00065, saving model to model_file.hdf5
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 6.4654e-04 - val_accuracy: 1.0000

# %%
def plot_accuracy_loss(history):

    fig = plt.figure(figsize=(10,5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "accuracy")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_accuracy")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %%
training_scores = model.evaluate(x_train, y_train)
print('low Training Loss:', training_scores[0])
print('good Training Accuracy:', training_scores[1])
# Out:
# 1/1 [==============================] - 0s 104ms/step - loss: 4.4673e-04 - accuracy: 1.0000
# low Training Loss: 0.00044673302909359336
# good Training Accuracy: 1.0

# %%
testing_scores = model.evaluate(x_test, y_test)
print('low Testing Loss:', testing_scores[0])
print('good  Testing Accuracy:', testing_scores[1])
# Out:
# 1/1 [==============================] - 0s 107ms/step - loss: 6.4654e-04 - accuracy: 1.0000
# low Testing Loss: 0.0006465350743383169
# good  Testing Accuracy: 1.0

# %%
preds = model.predict(x_test)
y_actual = []
y_pred = []

labels = encode.classes_
for idx, pred in enumerate(preds):
    y_actual.append(labels[np.argmax(y_test[idx])])
    y_pred.append(labels[np.argmax(pred)])

print(classification_report(y_pred, y_actual))
# Out:
# 1/1 [==============================] - 0s 246ms/step
#               precision    recall  f1-score   support
#
#      America       1.00      1.00      1.00         2
#       Indian       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
test.label.value_counts()
# Out:
# label
# America    2
# Indian     2
# Name: count, dtype: int64
